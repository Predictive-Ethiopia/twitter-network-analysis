# %% [markdown]
# # Twitter dataset analysis with Infomap

# %% [markdown]
# ## Run pipelines

# %%
# IMPORTS
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from orchestrator import Orchestrator
from analysis_helper import AnalysisHelper

# %%
# LOGGING LEVEL
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
# PATHS
PROJECT_PATH = os.path.abspath('')
INPUT_PATH = os.path.join(PROJECT_PATH, 'input/')
OUTPUT_PATH = os.path.join(PROJECT_PATH, 'output/')
PROJECT_NAME = 'ethiopia'

# %%
# PIPELINE
o = Orchestrator(PROJECT_NAME, INPUT_PATH, OUTPUT_PATH)
o.execute()
ah = AnalysisHelper(o.datasources)
# Out:
# reading input_contexts_path /mnt/10ac-team/notebooks/yabi/twitter-network-analysis/input/ethiopia/contexts.csv
# INFO - orchestrator - INIT Orchestrator
# INFO - orchestrator - START Orchestrator
# INFO - orchestrator - EXEC pipeline for ethiopia-national-dialogue
# INFO - pipelines.pipeline_base - INIT PIPELINE context_harvesting
# INFO - pipelines.pipeline_base - START PIPELINE context_harvesting
# INFO - pipelines.pipeline_base - START TASK __create_context
# INFO - pipelines.pipeline_base - END TASK __create_context
# INFO - pipelines.pipeline_base - START TASK __harvest_context
# INFO - pipelines.pipeline_base - END TASK __harvest_context
# INFO - pipelines.pipeline_base - START TASK __expand_context
# INFO - pipelines.pipeline_base - END TASK __expand_context
# INFO - pipelines.pipeline_base - END PIPELINE context_harvesting
# INFO - pipelines.pipeline_base - INIT PIPELINE network_creation
# INFO - pipelines.pipeline_base - START PIPELINE network_creation
# INFO - pipelines.pipeline_base - START TASK __create_network
# INFO - pipelines.pipeline_base - END TASK __create_network
# INFO - pipelines.pipeline_base - START TASK __create_nodes
# INFO - pipelines.pipeline_base - END TASK __create_nodes
# INFO - pipelines.pipeline_base - START TASK __create_edges
# INFO - pipelines.pipeline_base - END TASK __create_edges
# INFO - pipelines.pipeline_base - START TASK __create_graph
# INFO - pipelines.pipeline_base - END TASK __create_graph
# INFO - pipelines.pipeline_base - END PIPELINE network_creation
# INFO - pipelines.pipeline_base - INIT PIPELINE network_metrics
# INFO - pipelines.pipeline_base - START PIPELINE network_metrics
# INFO - pipelines.pipeline_base - END PIPELINE network_metrics
# INFO - pipelines.pipeline_base - INIT PIPELINE community_detection
# INFO - pipelines.pipeline_base - START PIPELINE community_detection
# INFO - pipelines.pipeline_base - START TASK __find_communities
# INFO - pipelines.pipeline_base - END TASK __find_communities
# INFO - pipelines.pipeline_base - START TASK __add_communities_to_nodes
# INFO - pipelines.pipeline_base - END TASK __add_communities_to_nodes
# INFO - pipelines.pipeline_base - END PIPELINE community_detection
# INFO - pipelines.pipeline_base - INIT PIPELINE community_detection_metrics
# INFO - pipelines.pipeline_base - START PIPELINE community_detection_metrics
# INFO - pipelines.pipeline_base - END PIPELINE community_detection_metrics
# INFO - pipelines.pipeline_base - INIT PIPELINE profile_metrics
# INFO - pipelines.pipeline_base - START PIPELINE profile_metrics
# INFO - pipelines.pipeline_base - START TASK __profile_info
# INFO - pipelines.pipeline_base - END TASK __profile_info
# INFO - pipelines.pipeline_base - END PIPELINE profile_metrics
# INFO - pipelines.pipeline_base - INIT PIPELINE usercontext_metrics
# INFO - pipelines.pipeline_base - START PIPELINE usercontext_metrics
# INFO - pipelines.pipeline_base - START TASK __get_user_stream
# INFO - pipelines.pipeline_base - END TASK __get_user_stream
# INFO - pipelines.pipeline_base - START TASK __compute_metrics
# INFO - pipelines.pipeline_base - END TASK __compute_metrics
# INFO - pipelines.pipeline_base - END PIPELINE usercontext_metrics
# INFO - pipelines.pipeline_base - INIT PIPELINE persistence
# INFO - pipelines.pipeline_base - START PIPELINE persistence
# INFO - pipelines.pipeline_base - START TASK __add_context
# datasource.files.read: full file name =   ethiopia-national-dialogue__context.csv
# INFO - pipelines.pipeline_base - END TASK __add_context
# INFO - pipelines.pipeline_base - START TASK __add_graph
# datasource.files.read: full file name =   ethiopia-national-dialogue__graph_summary.csv
# INFO - pipelines.pipeline_base - END TASK __add_graph
# INFO - pipelines.pipeline_base - START TASK __add_partition
# datasource.files.read: full file name =   ethiopia-national-dialogue__pquality.csv
# INFO - pipelines.pipeline_base - END TASK __add_partition
# INFO - pipelines.pipeline_base - START TASK __add_communities
# datasource.files.read: full file name =   ethiopia-national-dialogue__partition_summary.csv
# INFO - pipelines.pipeline_base - END TASK __add_communities
# INFO - pipelines.pipeline_base - START TASK __add_users
# datasource.files.read: full file name =   ethiopia-national-dialogue__profile_info.csv
# INFO - pipelines.pipeline_base - END TASK __add_users
# INFO - pipelines.pipeline_base - START TASK __add_profiles
# datasource.files.read: full file name =   ethiopia-national-dialogue__profiles.csv
# INFO - pipelines.pipeline_base - END TASK __add_profiles
# INFO - pipelines.pipeline_base - START TASK __add_user_communities
# datasource.files.read: full file name =   ethiopia-national-dialogue__nodes.csv
# INFO - pipelines.pipeline_base - END TASK __add_user_communities
# INFO - pipelines.pipeline_base - START TASK __add_user_context
# datasource.files.read: full file name =   ethiopia-national-dialogue__usercontext_metrics.csv
# INFO - pipelines.pipeline_base - END TASK __add_user_context
# INFO - pipelines.pipeline_base - END PIPELINE persistence
# INFO - orchestrator - EXEC pipeline for ethiopia
# INFO - pipelines.pipeline_base - INIT PIPELINE context_harvesting
# INFO - pipelines.pipeline_base - START PIPELINE context_harvesting
# INFO - pipelines.pipeline_base - START TASK __create_context
# INFO - pipelines.pipeline_base - END TASK __create_context
# INFO - pipelines.pipeline_base - START TASK __harvest_context
# INFO - pipelines.pipeline_base - END TASK __harvest_context
# INFO - pipelines.pipeline_base - START TASK __expand_context
# INFO - pipelines.pipeline_base - END TASK __expand_context
# INFO - pipelines.pipeline_base - END PIPELINE context_harvesting
# INFO - pipelines.pipeline_base - INIT PIPELINE network_creation
# INFO - pipelines.pipeline_base - START PIPELINE network_creation
# INFO - pipelines.pipeline_base - START TASK __create_network
# INFO - pipelines.pipeline_base - END TASK __create_network
# INFO - pipelines.pipeline_base - START TASK __create_nodes
# INFO - pipelines.pipeline_base - END TASK __create_nodes
# INFO - pipelines.pipeline_base - START TASK __create_edges
# INFO - pipelines.pipeline_base - END TASK __create_edges
# INFO - pipelines.pipeline_base - START TASK __create_graph
# INFO - pipelines.pipeline_base - END TASK __create_graph
# INFO - pipelines.pipeline_base - END PIPELINE network_creation
# INFO - pipelines.pipeline_base - INIT PIPELINE network_metrics
# INFO - pipelines.pipeline_base - START PIPELINE network_metrics
# INFO - pipelines.pipeline_base - END PIPELINE network_metrics
# INFO - pipelines.pipeline_base - INIT PIPELINE community_detection
# INFO - pipelines.pipeline_base - START PIPELINE community_detection
# INFO - pipelines.pipeline_base - START TASK __find_communities
# INFO - pipelines.pipeline_base - END TASK __find_communities
# INFO - pipelines.pipeline_base - START TASK __add_communities_to_nodes
# INFO - pipelines.pipeline_base - END TASK __add_communities_to_nodes
# INFO - pipelines.pipeline_base - END PIPELINE community_detection
# INFO - pipelines.pipeline_base - INIT PIPELINE community_detection_metrics
# INFO - pipelines.pipeline_base - START PIPELINE community_detection_metrics
# INFO - pipelines.pipeline_base - END PIPELINE community_detection_metrics
# INFO - pipelines.pipeline_base - INIT PIPELINE profile_metrics
# INFO - pipelines.pipeline_base - START PIPELINE profile_metrics
# INFO - pipelines.pipeline_base - START TASK __profile_info
# INFO - pipelines.pipeline_base - END TASK __profile_info
# INFO - pipelines.pipeline_base - END PIPELINE profile_metrics
# INFO - pipelines.pipeline_base - INIT PIPELINE usercontext_metrics
# INFO - pipelines.pipeline_base - START PIPELINE usercontext_metrics
# INFO - pipelines.pipeline_base - START TASK __get_user_stream
# INFO - pipelines.pipeline_base - END TASK __get_user_stream
# INFO - pipelines.pipeline_base - START TASK __compute_metrics
# INFO - pipelines.pipeline_base - END TASK __compute_metrics
# INFO - pipelines.pipeline_base - END PIPELINE usercontext_metrics
# INFO - pipelines.pipeline_base - INIT PIPELINE persistence
# INFO - pipelines.pipeline_base - START PIPELINE persistence
# INFO - pipelines.pipeline_base - START TASK __add_context
# datasource.files.read: full file name =   ethiopia__context.csv
# INFO - pipelines.pipeline_base - END TASK __add_context
# INFO - pipelines.pipeline_base - START TASK __add_graph
# datasource.files.read: full file name =   ethiopia__graph_summary.csv
# INFO - pipelines.pipeline_base - END TASK __add_graph
# INFO - pipelines.pipeline_base - START TASK __add_partition
# datasource.files.read: full file name =   ethiopia__pquality.csv
# INFO - pipelines.pipeline_base - END TASK __add_partition
# INFO - pipelines.pipeline_base - START TASK __add_communities
# datasource.files.read: full file name =   ethiopia__partition_summary.csv
# INFO - pipelines.pipeline_base - END TASK __add_communities
# INFO - pipelines.pipeline_base - START TASK __add_users
# datasource.files.read: full file name =   ethiopia__profile_info.csv
# INFO - pipelines.pipeline_base - END TASK __add_users
# INFO - pipelines.pipeline_base - START TASK __add_profiles
# datasource.files.read: full file name =   ethiopia__profiles.csv
# INFO - pipelines.pipeline_base - END TASK __add_profiles
# INFO - pipelines.pipeline_base - START TASK __add_user_communities
# datasource.files.read: full file name =   ethiopia__nodes.csv
# INFO - pipelines.pipeline_base - END TASK __add_user_communities
# INFO - pipelines.pipeline_base - START TASK __add_user_context
# datasource.files.read: full file name =   ethiopia__usercontext_metrics.csv
# INFO - pipelines.pipeline_base - END TASK __add_user_context
# INFO - pipelines.pipeline_base - END PIPELINE persistence
# INFO - pipelines.pipeline_base - INIT PIPELINE ranking
# INFO - pipelines.pipeline_base - START PIPELINE ranking
# INFO - pipelines.pipeline_base - START TASK __get_active_users
# INFO - pipelines.pipeline_base - END TASK __get_active_users
# INFO - pipelines.pipeline_base - END PIPELINE ranking
# INFO - pipelines.pipeline_base - INIT PIPELINE user_timelines
# INFO - pipelines.pipeline_base - START PIPELINE user_timelines
# INFO - pipelines.pipeline_base - START TASK __get_user_timelines
# INFO - pipelines.pipeline_base - END TASK __get_user_timelines
# INFO - pipelines.pipeline_base - END PIPELINE user_timelines
# INFO - pipelines.pipeline_base - INIT PIPELINE bipartite_graph
# INFO - pipelines.pipeline_base - START PIPELINE bipartite_graph
# INFO - pipelines.pipeline_base - START TASK __get_user_hashtag_network
# INFO - pipelines.pipeline_base - END TASK __get_user_hashtag_network
# INFO - pipelines.pipeline_base - START TASK __get_user_hashtag_graph
# INFO - pipelines.pipeline_base - END TASK __get_user_hashtag_graph
# INFO - pipelines.pipeline_base - END PIPELINE bipartite_graph
# INFO - pipelines.pipeline_base - INIT PIPELINE bipartite_community_detection
# INFO - pipelines.pipeline_base - START PIPELINE bipartite_community_detection
# INFO - pipelines.pipeline_base - START TASK __find_communities
# datasource.files.read: full file name =   graph.gexf
# datasource.files.write: full file name =   multiplex_graph.gexf
# INFO - pipelines.pipeline_base - END TASK __find_communities
# INFO - pipelines.pipeline_base - END PIPELINE bipartite_community_detection
# INFO - pipelines.pipeline_base - INIT PIPELINE context_detector
# INFO - pipelines.pipeline_base - START PIPELINE context_detector
# INFO - pipelines.pipeline_base - START TASK __hashtags_frequency
# INFO - pipelines.pipeline_base - END TASK __hashtags_frequency
# INFO - pipelines.pipeline_base - START TASK __find_peaks
# INFO - pipelines.pipeline_base - END TASK __find_peaks
# INFO - pipelines.pipeline_base - START TASK __get_ranked_users_with_hashtags
# INFO - pipelines.pipeline_base - END TASK __get_ranked_users_with_hashtags
# INFO - pipelines.pipeline_base - START TASK get_new_contexts
# INFO - pipelines.pipeline_base - END TASK get_new_contexts
# INFO - pipelines.pipeline_base - END PIPELINE context_detector
# INFO - orchestrator - END Orchestrator

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Context and graph analysis

# %%
ah.get_new_contexts()['context_hashtags'].to_list()
# Out:
# datasource.files.read: full file name =   new_contexts.csv
# [['#tigraygenocide',
#   '#stoptigraygenocide',
#   '#stopbombingtigray',
#   '#stoptigrayfamine'],
#  ['#ethiopian', '#ethiopians', '#nomore', '#ethiopiaprevails']]

# %%
display(ah.show_peaks(['#tigraygenocide',
'#stoptigraygenocide',
'#stopbombingtigray',
'#stoptigrayfamine']))
# Out:
# datasource.files.read: full file name =   hashtags_frequency.csv
# datasource.files.read: full file name =   hashtags_peaks.csv
# None

# %%
display(ah.show_peaks(['#ethiopian', '#ethiopians', '#nomore', '#ethiopiaprevails']))
# Out:
# datasource.files.read: full file name =   hashtags_frequency.csv
# datasource.files.read: full file name =   hashtags_peaks.csv
# None

# %%
ah.plot_tweets_distribution()
# Out:
# datasource.files.read: full file name =   rank_3.csv
# datasource.files.read: full file name =   user_timelines.csv
# Users selected for harvesting: 50 (actual 50)/ 280
# Number of posted tweets: 6623
# Users posted a min of 2 and a max of 200 tweets

# %%
ah.hashtags_stats()
# Out:
# datasource.files.read: full file name =   hashtags_peaks.csv
#                     hashtag  peak_value  peak_date  peak_width start_date  \
# 0                 #eritrean    0.161692 2022-01-08           1 2022-01-08
# 1                #ethiopian    0.564210 2022-01-08           3 2022-01-06
# 2               #ethiopians    0.161692 2022-01-08           3 2022-01-06
# 3         #ethiopiaprevails    0.765469 2022-01-08           3 2022-01-06
# 4   #medicalsupplyfortigray    0.664839 2022-01-08           3 2022-01-06
# 5                   #nomore    1.671134 2022-01-08           8 2022-01-01
# 6        #stopbombingtigray    1.939479 2022-01-08           3 2022-01-06
# 7         #stoptigrayfamine    0.228779 2022-01-07           5 2022-01-05
# 8       #stoptigraygenocide    1.167987 2022-01-08           1 2022-01-08
# 9           #tigraygenocide    4.220412 2022-01-08           7 2022-01-02
# 10                #unactnow    0.564210 2022-01-08           1 2022-01-08
#
#      end_date
# 0  2022-01-08
# 1  2022-01-08
# 2  2022-01-08
# 3  2022-01-08
# 4  2022-01-08
# 5  2022-01-08
# 6  2022-01-08
# 7  2022-01-09
# 8  2022-01-08
# 9  2022-01-08
# 10 2022-01-08

# %%
ah.communities_hashtags()
# Out:
# datasource.files.read: full file name =   multiplex_graph.gexf
# datasource.files.read: full file name =   hashtags_peaks.csv
#                hashtag  peak_value  peak_date  peak_width start_date  \
# 1           #ethiopian    0.564210 2022-01-08           3 2022-01-06
# 2          #ethiopians    0.161692 2022-01-08           3 2022-01-06
# 3    #ethiopiaprevails    0.765469 2022-01-08           3 2022-01-06
# 5              #nomore    1.671134 2022-01-08           8 2022-01-01
# 6   #stopbombingtigray    1.939479 2022-01-08           3 2022-01-06
# 7    #stoptigrayfamine    0.228779 2022-01-07           5 2022-01-05
# 8  #stoptigraygenocide    1.167987 2022-01-08           1 2022-01-08
# 9      #tigraygenocide    4.220412 2022-01-08           7 2022-01-02
#
#     end_date  community  degree
# 1 2022-01-08          2      31
# 2 2022-01-08          2      24
# 3 2022-01-08          2      14
# 5 2022-01-08          2      23
# 6 2022-01-08          1      24
# 7 2022-01-09          1      18
# 8 2022-01-08          1      23
# 9 2022-01-08          1      35

# %%
ah.bigraph_stats_bycomm()
# Out:
# datasource.files.read: full file name =   multiplex_graph.gexf
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/networkx/algorithms/assortativity/correlation.py:282: RuntimeWarning: invalid value encountered in double_scalars
#   return (xy * (M - ab)).sum() / np.sqrt(vara * varb)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/networkx/algorithms/assortativity/mixing.py:208: RuntimeWarning: invalid value encountered in true_divide
#   a = a / a.sum()
#              topic  community  no_nodes  no_edges  avg_degree  \
# 0        #ethiopia          0        22       121   11.000000
# 1  #tigraygenocide          1        11        47    8.545455
# 2       #ethiopian          2        10        30    6.000000
# 3         #eritrea          3         5         8    3.200000
# 4          #amhara          4         2         1    1.000000
# 5           #china          5         1         0    0.000000
#
#    avg_weighted_degree   density  avg_clustering  assortativity
# 0           189.545455  0.523810        0.616758      -0.498410
# 1           122.727273  0.854545        0.918687      -0.264683
# 2            70.000000  0.666667        0.842857      -0.599229
# 3            16.000000  0.800000        0.666667      -0.333333
# 4             6.000000  1.000000        0.000000            NaN
# 5             0.000000  0.000000        0.000000            NaN

# %%
ah.get_common_nodes()
# Out:
# datasource.files.read: full file name =   ethiopia-national-dialogue__nodes.csv
# datasource.files.read: full file name =   ethiopia__nodes.csv
#                                            name                          url  \
# abiyahmedali                  Abiy Ahmed Ali 🇪🇹                         None
# norwayun                               NorwayUN                         None
# who             World Health Organization (WHO)                         None
# usaid                                     USAID                         None
# ukun_newyork                    UK at the UN 🇬🇧                         None
# tigray21ginbot          Kingdom Of Great Tigray                         None
# statedeptspox                         Ned Price                         None
# statedept                   Department of State                         None
# stalinteklu                Stalin Gebreselassie       https://www.tmhtv.org/
# soli1234567890              Selu_Tigraweyti💛❤️💊                         None
# powerusaid                       Samantha Power                         None
# mukeshkapila                      Mukesh Kapila                         None
# amnesty                   Amnesty International  https://www.amnesty.org/en/
# mona_juul                             Mona Juul                         None
# iyoba4u                           Iyoba 🇪🇹 💚💛♥️                         None
# irishmissionun                    Ireland at UN                         None
# hrw                          Human Rights Watch                         None
# hermelatv                       hermela aregawi                         None
# franceonu                La France à l'ONU 🇫🇷🇪🇺                         None
# flyethiopian                 Ethiopian Airlines                         None
# estoniaun                         Estonia in UN                         None
# danigidena                       Danu Axsumawit                         None
# zewdu_mawcha                          Zewdu ❤💛🌹                         None
#
#                                       location  \
# abiyahmedali                          Ethiopia
# norwayun                         New York City
# who                        Geneva, Switzerland
# usaid                                     None
# ukun_newyork                      New York, NY
# tigray21ginbot                            None
# statedeptspox   Dept. of State, Washington, DC
# statedept                       Washington, DC
# stalinteklu                     Washington, DC
# soli1234567890                            None
# powerusaid                    Washington, D.C.
# mukeshkapila                            Global
# amnesty                                 Global
# mona_juul                         New York, NY
# iyoba4u                               Ethiopia
# irishmissionun                        New York
# hrw                                       None
# hermelatv                      Los Angeles, CA
# franceonu                             New York
# flyethiopian             Addis Ababa, Ethiopia
# estoniaun                                 None
# danigidena                                None
# zewdu_mawcha                              None
#
#                                                               bio language  \
# abiyahmedali    Prime Minister of the Federal Democratic Repub...     None
# norwayun        Norway's @UN Mission in New York 🇺🇳🇳🇴 Consiste...     None
# who             We are the #UnitedNations’ health agency - #He...     None
# usaid           We provide development and humanitarian assist...     None
# ukun_newyork    British diplomacy, *280* characters at a time....     None
# tigray21ginbot  Tigrean Man Of Freedom !!  The people of Tigra...     None
# statedeptspox   The official account of @StateDept’s Spokesper...     None
# statedept       Welcome to the U.S. Department of State Twitte...     None
# stalinteklu     Journalist (Tigrai Media House), Human Rights ...     None
# soli1234567890  ቅያ , ትግራወይቲ 💛❤️            ህዝቢ ትግራይ ይዕወት💯💛❤️ ን...     None
# powerusaid      Declan and Rían's mom, 🇮🇪 Immigrant, married t...     None
# mukeshkapila    Author & Writer, Professor Emerit. Global Heal...     None
# amnesty         We defend human rights around the world. No go...     None
# mona_juul       Norway's Ambassador and Permanent Representati...     None
# iyoba4u         Prospect to #PhD - We Have To Live The Dream, ...     None
# irishmissionun  News from 🇮🇪's Mission to the #UN 🇺🇳 Elected m...     None
# hrw             Exposing #HumanRights abuses around the world....     None
# hermelatv       Journalist. (Resume: @cbsla @aljazeera @TheYou...     None
# franceonu       Mission permanente de la France auprès de l'ON...     None
# flyethiopian    Ethiopian Airlines offers world-class passenge...     None
# estoniaun       Permanent Mission of Estonia to the United Nat...     None
# danigidena                                       ኣኽሱማዊት (Tdf) 💊💊✊     None
# zewdu_mawcha                                         gal shire❤💛❤     None
#
#                  likes  follower_rank  no_participations
# abiyahmedali        20       1.000000                  2
# norwayun         19525       0.953172                  2
# who              11950       0.999833                  2
# usaid            25517       0.999062                  2
# ukun_newyork      9492       0.981730                  2
# tigray21ginbot    9575       0.612959                  2
# statedeptspox       63       0.999938                  2
# statedept           47       0.999964                  2
# stalinteklu          5       0.999328                  2
# soli1234567890    6307       0.475228                  2
# powerusaid         341       0.995479                  2
# mukeshkapila      3839       0.877651                  2
# amnesty           1355       0.998004                  2
# mona_juul         2255       0.907560                  2
# iyoba4u         187843       0.944295                  2
# irishmissionun    9154       0.947312                  2
# hrw              15311       0.995624                  2
# hermelatv         6868       0.989239                  2
# franceonu        17390       0.983754                  2
# flyethiopian      6690       0.999844                  2
# estoniaun        15037       0.941437                  2
# danigidena       10723       0.671145                  2
# zewdu_mawcha     17776       0.580369                  2

# %%
ah.get_user_timelines()
# Out:
# datasource.files.read: full file name =   user_timelines.csv
#                     tw_id        user_name                date lang  no_likes  \
# 0     1479823652413657089       awethailes 2022-01-08 14:33:47   en         0
# 1     1479823479205728260       awethailes 2022-01-08 14:33:05   en         0
# 2     1479822111015325700       awethailes 2022-01-08 14:27:39   en         0
# 3     1479775684415434756       awethailes 2022-01-08 11:23:10   en         0
# 4     1479774711726972928       awethailes 2022-01-08 11:19:18   en         0
# ...                   ...              ...                 ...  ...       ...
# 6618  1480001675196657671  abraham85702013 2022-01-09 02:21:11   en         0
# 6619  1480001660051025921  abraham85702013 2022-01-09 02:21:07   en         0
# 6620  1480001647979864066  abraham85702013 2022-01-09 02:21:04   en         0
# 6621  1480001635099107329  abraham85702013 2022-01-09 02:21:01   en         0
# 6622  1480001619051773956  abraham85702013 2022-01-09 02:20:57   en         0
#
#       no_retweets  is_retweet  reply  \
# 0            1127        True    NaN
# 1             409        True    NaN
# 2             659        True    NaN
# 3             497        True    NaN
# 4             435        True    NaN
# ...           ...         ...    ...
# 6618           30        True    NaN
# 6619           41        True    NaN
# 6620           53        True    NaN
# 6621           54        True    NaN
# 6622           44        True    NaN
#
#                                                    text  is_media  \
# 0                     Are Not ? Nothing to celebrate...     False
# 1     New article! Iranian Drone Munitions Found In ...     False
# 2     The war in has displaced almost 2 million peop...     False
# 3     The says the federal government of is operatin...     False
# 4     The top hospital in has not received a resuppl...     False
# ...                                                 ...       ...
# 6618  Invading Eritrean forces entered via Irob, mas...     False
# 6619  This time last year, the horrific unfolded cla...     False
# 6620  The minority of Tigray who never fully recover...     False
# 6621  This time last year, the horrific unfolded cla...     False
# 6622  This time last year, the horrific unfolded cla...     False
#
#                                                hashtags             mentions  \
# 0     [#tigrayans, #ethiopians, #greatethiopianhomec...          [artssiyad]
# 1                                                    []      [oryxspioenkop]
# 2                                  [#tigray, #ethiopia]    [gerrysimpsonhrw]
# 3                                  [#ethiopia, #tigray]  [roncliffeodit, un]
# 4                                             [#tigray]     [realhaulegluck]
# ...                                                 ...                  ...
# 6618                                          [#tigray]      [samri44540293]
# 6619                                    [#irobmassacre]        [hailetsigab]
# 6620                                            [#irob]    [titigebremedhin]
# 6621                                    [#irobmassacre]    [teklay_zebrhan1]
# 6622                                    [#irobmassacre]           [sabawitq]
#
#                                                    urls  \
# 0                                                    []
# 1     [https://www.oryxspioenkop.com/2022/01/iranian...
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 6618                                                 []
# 6619                                                 []
# 6620                                                 []
# 6621                                                 []
# 6622                                                 []
#
#                                      retweeted_hashtags
# 0     ['#tigrayans', '#ethiopians', '#greatethiopian...
# 1                                                    []
# 2                              ['#tigray', '#ethiopia']
# 3                              ['#ethiopia', '#tigray']
# 4                                           ['#tigray']
# ...                                                 ...
# 6618                                        ['#tigray']
# 6619                                  ['#irobmassacre']
# 6620                                          ['#irob']
# 6621                                  ['#irobmassacre']
# 6622                                  ['#irobmassacre']
#
# [6623 rows x 14 columns]

# %% [markdown]
# #### Context summary

# %%
display(ah.get_contexts())
# Out:
#                             start_date    end_date location  \
# name
# ethiopia-national-dialogue  2021-12-15  2022-01-07     None
# ethiopia                    2022-01-01  2022-01-08     None
#
#                                                                      hashtags
# name
# ethiopia-national-dialogue      #ethiopiadialogue #ethiopia #nationaldialogue
# ethiopia                    #tigray #oromia #gondar #amhar #ethiopia #nati...

# %% [markdown]
# ## Ranking

# %%
ah.get_rank_1().head(100)
# Out:
# datasource.files.read: full file name =   rank_1.csv
#           user_name    rank
# id
# 119    ukun_newyork  68.069
# 45        estoniaun  68.058
# 67   irishmissionun  68.036
# 87         norwayun  68.028
# 52        franceonu  68.000
# ..              ...     ...
# 158      bashadesta   4.556
# 189   gbellatesfay2   4.452
# 254       seifgebre   4.325
# 152         arayayb   4.311
# 148   almaz20053861   4.290
#
# [100 rows x 2 columns]

# %% [markdown]
# Ranking function that takes into account:
# * *Inverse in-degree*: In the considered graphs the hubs in the communities seems to be mostly related to associations and organizations. The smaller ones are more likely to be individuals.
# * *Topical focus*: related to the interest the users have on the topic.
#
# Formula:
# \begin{align}
# \mathit{R1}(u) & = \frac{1}{\sum_{u \in C} \mathit{IC}(u) + 1} \cdot \sum_{u \in C} \mathit{TF}(u)
# \end{align}

# %%
ah.get_rank_2().head(10)
# Out:
# datasource.files.read: full file name =   rank_2.csv
#            user_name      rank
# id
# 74   kibrommulugeta6  0.681205
# 123      tigrayhaben  0.299953
# 80        mediakaleb  0.212457
# 118  tesfaye95150785  0.183526
# 39     destinystamp1  0.175906
# 124     tigrayteserr  0.159182
# 14   amandaruthprice  0.145514
# 33      cteklebirhan  0.143226
# 5        abadi1_mulu  0.141482
# 78    mathewosdesta2  0.134741

# %% [markdown]
# Formula:
#
# \begin{align}
# \mathit{R2}(u) & = \lvert \mathit{FR}(u) - 1 \rvert \cdot \left(\sum_{u \in C} \mathit{TA}(U) + \sum_{u \in C} \mathit{IC}(U)\right)
# \end{align}

# %%
ah.get_rank_3().head(10)
# Out:
# datasource.files.read: full file name =   rank_3.csv
#          user_name      rank
# id
# 154     awethailes  1.395748
# 243  rahel47103655  1.287255
# 161      biniam_g4  1.249717
# 194      hanalema4  1.203549
# 244      rassolom2  1.167953
# 156       ayakunim  1.139433
# 185   eyobkidane19  1.132787
# 40   dessalewadane  1.023534
# 272   tigraybethel  0.986849
# 218       letkidan  0.986822

# %% [markdown]
# Formula:
#
# \begin{align}
# \mathit{R3}(u) & = \lvert \mathit{FR}(u) - 1 \rvert \cdot \left(\sum_{u \in C} \mathit{TA}(U) + \frac{1}{\sum_{u \in C} \mathit{IC}(U) + 1}\right)
# \end{align}

# %% [markdown]
# # Similarity analysis between users

# %% [markdown]
# ## TF-IDF

# %%
hashtags_vector = ah.get_bow()
#print(df.info())
#hashtags_vector = df.pivot_table(columns='hashtag', index='user_name',values='weights',aggfunc='sum') 
print(hashtags_vector.shape)
hashtags_vector.head(10)
# Out:
# datasource.files.read: full file name =   user_hashtag_network.csv
# (49, 455)
# hashtag          #1yearirobmassacre  #1yearoftigraygenocide  #2022newyear  \
# user_name
# 0uz7ktrk5jmlmzq                   0                       0             0
# 2d9cx8mvd7                        0                       0             0
# 5sd2gygxnkfk7eb                   0                       1             0
# abraham85702013                   1                       0             0
# akins_yusuf                       0                       0             1
# aku91566837                       0                       0             0
# amare_smere                       0                       0             0
# awethailes                        0                       0             0
# ayakunim                          0                       0             0
# azeneelias                        0                       0             0
#
# hashtag          #428daysoftigraygenocide  #433daysoftigraygenocide  #56idps  \
# user_name
# 0uz7ktrk5jmlmzq                         0                         0        0
# 2d9cx8mvd7                              0                         0        0
# 5sd2gygxnkfk7eb                         0                         0        1
# abraham85702013                         0                         1        0
# akins_yusuf                             0                         0        0
# aku91566837                             0                         0        0
# amare_smere                             0                         0        0
# awethailes                              0                         0        0
# ayakunim                                0                         0        0
# azeneelias                              0                         0        0
#
# hashtag          #abala  #abiy  #abiyahmed  #abiyahmedali  ...  #ይፍቱኝ_አባቴ  \
# user_name                                                  ...
# 0uz7ktrk5jmlmzq       0      1           0              0  ...          0
# 2d9cx8mvd7            0      0           0              0  ...          0
# 5sd2gygxnkfk7eb       0      0           4              0  ...          0
# abraham85702013       0      0           1              0  ...          0
# akins_yusuf           0      0           0              0  ...          0
# aku91566837           0      0           0              0  ...          0
# amare_smere           0      0           1              0  ...          0
# awethailes            0      0           0              0  ...          0
# ayakunim              0      0           4              0  ...          2
# azeneelias            0      1           0              0  ...          0
#
# hashtag          #ድምፂ  #ጀግናችን  #ጌታ  #ጌዜ  #ግድቡ_የእኔ_ነው  #ጥያቄ  #ፍቅር  #ፍትህ  #ፖርቲን
# user_name
# 2d9cx8mvd7       0.00000  0.000000    0.000000        0.00000  ...    0.00000
# 5sd2gygxnkfk7eb  0.00000  0.000000    3.026915        0.00000  ...    0.00000
# abraham85702013  0.00000  0.000000    0.756729        0.00000  ...    0.00000
# akins_yusuf      0.00000  0.000000    0.000000        0.00000  ...    0.00000
# aku91566837      0.00000  0.000000    0.000000        0.00000  ...    0.00000
# amare_smere      0.00000  0.000000    0.756729        0.00000  ...    0.00000
# awethailes       0.00000  0.000000    0.000000        0.00000  ...    0.00000
# ayakunim         0.00000  0.000000    3.026915        0.00000  ...   11.22942
# azeneelias       0.00000  4.029747    0.000000        0.00000  ...    0.00000
# betelihemzenebe  0.00000  0.000000    4.540373        9.22942  ...    0.00000
# beth81450411     0.00000  0.000000    1.513458        0.00000  ...    0.00000
# biniam_g4        0.00000  0.000000    1.513458        0.00000  ...    0.00000
# birukta41338328  0.00000  0.000000    0.000000        0.00000  ...    0.00000
# capitalmj12      0.00000  0.000000    0.756729        0.00000  ...    0.00000
# darkedars        0.00000  0.000000    0.000000        0.00000  ...    0.00000
# dawitmesfun      0.00000  0.000000    1.513458        0.00000  ...    0.00000
# ethio20211       0.00000  0.000000    0.000000        0.00000  ...    0.00000
# eyobkidane19     0.00000  0.000000    3.026915        0.00000  ...    0.00000
# hanalema4        0.00000  0.000000    0.756729        0.00000  ...    0.00000
# helena12113686   0.00000  0.000000    0.756729        0.00000  ...    0.00000
# henok80180552    0.00000  0.000000    1.513458        0.00000  ...    0.00000
# jenettdf         0.00000  0.000000    1.513458        0.00000  ...    0.00000
# kalebgebremar19  0.00000  0.000000    2.270187        0.00000  ...    0.00000
# leenale05130237  0.00000  0.000000    0.000000        0.00000  ...    0.00000
# letkidan         0.00000  0.000000    0.756729        0.00000  ...    0.00000
# mekdjib          0.00000  0.000000    0.000000        0.00000  ...    0.00000
# metekeya         0.00000  4.029747    0.756729        0.00000  ...    0.00000
# michalegebrezg3  0.00000  0.000000    1.513458        0.00000  ...    0.00000
# mulugetadesta5   0.00000  0.000000    0.000000        0.00000  ...    0.00000
# nh91683451       0.00000  0.000000    3.783644        0.00000  ...    0.00000
# nigmit           0.00000  0.000000    0.756729        0.00000  ...    0.00000
# rahel47103655    0.00000  0.000000    0.000000        0.00000  ...    0.00000
# rassolom2        0.00000  0.000000    2.270187        4.61471  ...    0.00000
# rekt5gyihnbr731  0.00000  0.000000    0.756729        0.00000  ...    0.00000
# sabawitq         0.00000  0.000000    3.026915        0.00000  ...    0.00000
# saliemhadera18   0.00000  0.000000    0.000000        0.00000  ...    0.00000
# soli1234567890   0.00000  0.000000    4.540373        0.00000  ...    0.00000
# tadesse67945510  5.61471  0.000000    2.270187        0.00000  ...    0.00000
# teshomemedhanit  0.00000  0.000000    0.000000        0.00000  ...    0.00000
# tigraweyeti      0.00000  0.000000    0.756729        0.00000  ...    0.00000
# tigraybethel     0.00000  0.000000    2.270187        0.00000  ...    0.00000
# tigrayhorn       0.00000  0.000000    3.026915        0.00000  ...    0.00000
# tigrayismy       0.00000  0.000000    0.756729        0.00000  ...    0.00000
# tilahunbefikadu  0.00000  0.000000    0.000000        0.00000  ...    0.00000
# tmah1670         0.00000  0.000000    0.000000        0.00000  ...    0.00000
# yamieatz         0.00000  0.000000    0.000000        0.00000  ...    0.00000
# yirguedilu       0.00000  0.000000    0.000000        0.00000  ...    0.00000
# zet2950          0.00000  0.000000    0.000000        0.00000  ...    0.00000
#
# hashtag              #ድምፂ   #ጀግናችን      #ጌታ      #ጌዜ  #ግድቡ_የእኔ_ነው     #ጥያቄ  \
# user_name
# 0uz7ktrk5jmlmzq   0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# 2d9cx8mvd7        0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# 5sd2gygxnkfk7eb   0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# abraham85702013   0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# akins_yusuf       0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# aku91566837       0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# amare_smere       0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# awethailes        0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# ayakunim          0.00000  0.00000  0.00000  5.61471      5.61471  0.00000
# azeneelias        0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# betelihemzenebe   0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# beth81450411      0.00000  0.00000  5.61471  0.00000      0.00000  0.00000
# biniam_g4         0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# birukta41338328   0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# capitalmj12       0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# darkedars         0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# dawitmesfun       0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# ethio20211        0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# eyobkidane19      0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# hanalema4        11.22942  0.00000  0.00000  0.00000      0.00000  0.00000
# helena12113686    0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# henok80180552     0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# jenettdf          0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# kalebgebremar19   0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# leenale05130237   0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# letkidan          0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# mekdjib           0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# metekeya          0.00000  5.61471  0.00000  0.00000      0.00000  5.61471
# michalegebrezg3   0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# mulugetadesta5    0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# nh91683451        0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# nigmit            0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# rahel47103655     0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# rassolom2         0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# rekt5gyihnbr731   0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# sabawitq          0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# saliemhadera18    0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# soli1234567890    0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# tadesse67945510   0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# teshomemedhanit   0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# tigraweyeti       0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# tigraybethel      0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# tigrayhorn        0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# tigrayismy        0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# tilahunbefikadu   0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# tmah1670          0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# yamieatz          0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# yirguedilu        0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
# zet2950           0.00000  0.00000  0.00000  0.00000      0.00000  0.00000
#
# hashtag             #ፍቅር     #ፍትህ    #ፖርቲን
# user_name
# 0uz7ktrk5jmlmzq  0.00000  0.00000  0.00000
# 2d9cx8mvd7       0.00000  0.00000  0.00000
# 5sd2gygxnkfk7eb  0.00000  0.00000  0.00000
# abraham85702013  0.00000  0.00000  0.00000
# akins_yusuf      0.00000  0.00000  0.00000
# aku91566837      0.00000  0.00000  0.00000
# amare_smere      0.00000  0.00000  0.00000
# awethailes       0.00000  0.00000  0.00000
# ayakunim         5.61471  0.00000  0.00000
# azeneelias       0.00000  0.00000  0.00000
# betelihemzenebe  0.00000  0.00000  0.00000
# beth81450411     0.00000  0.00000  0.00000
# biniam_g4        0.00000  0.00000  0.00000
# birukta41338328  0.00000  0.00000  0.00000
# capitalmj12      0.00000  0.00000  0.00000
# darkedars        0.00000  0.00000  0.00000
# dawitmesfun      0.00000  0.00000  0.00000
# ethio20211       0.00000  0.00000  0.00000
# eyobkidane19     0.00000  0.00000  0.00000
# hanalema4        0.00000  0.00000  0.00000
# helena12113686   0.00000  0.00000  0.00000
# henok80180552    0.00000  0.00000  0.00000
# jenettdf         0.00000  0.00000  0.00000
# kalebgebremar19  0.00000  0.00000  0.00000
# leenale05130237  0.00000  0.00000  0.00000
# letkidan         0.00000  0.00000  0.00000
# mekdjib          0.00000  0.00000  0.00000
# metekeya         0.00000  0.00000  0.00000
# michalegebrezg3  0.00000  0.00000  0.00000
# mulugetadesta5   0.00000  0.00000  0.00000
# nh91683451       0.00000  0.00000  0.00000
# nigmit           0.00000  0.00000  0.00000
# rahel47103655    0.00000  0.00000  0.00000
# rassolom2        0.00000  0.00000  0.00000
# rekt5gyihnbr731  0.00000  0.00000  0.00000
# sabawitq         0.00000  0.00000  0.00000
# saliemhadera18   0.00000  0.00000  0.00000
# soli1234567890   0.00000  0.00000  0.00000
# tadesse67945510  0.00000  0.00000  0.00000
# teshomemedhanit  0.00000  0.00000  0.00000
# tigraweyeti      0.00000  0.00000  0.00000
# tigraybethel     0.00000  0.00000  0.00000
# tigrayhorn       0.00000  0.00000  0.00000
# tigrayismy       0.00000  0.00000  0.00000
# tilahunbefikadu  0.00000  5.61471  5.61471
# tmah1670         0.00000  0.00000  0.00000
# yamieatz         0.00000  0.00000  0.00000
# yirguedilu       0.00000  0.00000  0.00000
# zet2950          0.00000  0.00000  0.00000
#
# [49 rows x 455 columns]

# %%
tf_idf_mean = tf_idf.mean()

# %%
ah.print_full(tf_idf_mean.sort_values(ascending=False).head(10))
# Out:
# hashtag
# #tigray                             12.18
# #nomore                              5.84
# #noflyzoneintigray                   4.49
# #tigraygenocide                      4.34
# #ethiopiaprevails                    4.29
# #stopbombingtigray                   4.13
# #unityforethiopia                    3.96
# #endtigraysiege                      3.41
# #irobmassacre                        3.32
# #quote                               2.86
# dtype: float64

# %%
context_hashtag_list = ah.get_contexts()['hashtags'].str.split().sum()

# %% [markdown]
# Hashtags in common between hashtags from contexts and top (same length) hashtags from tf-idf first and frequency second.
#
# Frequency has more hashtags in common wrt tf-idf.
#
# beware: hashtags from 1 whole year are harvested for tfidf and frequency sets, so possibly more events are included

# %%
len(set(tf_idf_mean.sort_values(ascending=False)
        .head(len(context_hashtag_list)).index.tolist()) &
    set(context_hashtag_list))/len(context_hashtag_list)
# Out:
# 0.14285714285714285

# %%
len(set(hashtags_vector.sum().sort_values(ascending=False)
        .head(len(context_hashtag_list)).index.tolist()) &
    set(context_hashtag_list))/len(context_hashtag_list)
# Out:
# 0.2857142857142857

# %% [markdown]
# ## Bipartite graph

# %%
unique_frequencies = set()
hashtags_vector.apply(lambda x: unique_frequencies.update(x.unique()), axis=0)
unique_frequencies.remove(0)

# %%
import pandas as pd
import networkx as nx
freqs_pairs = pd.DataFrame({'frequencies': list(unique_frequencies)}).set_index('frequencies')
freqs_pairs['edges'] =\
freqs_pairs.index.map(lambda i: [(hashtags_vector.index[x], hashtags_vector.columns[y])
                                 for x, y in zip(*np.where(hashtags_vector.values == i))])
freqs_pairs.head(10)
# Out:
#                                                          edges
# frequencies
# 1            [(0uz7ktrk5jmlmzq, #abiy), (0uz7ktrk5jmlmzq, #...
# 2            [(0uz7ktrk5jmlmzq, #africa), (0uz7ktrk5jmlmzq,...
# 3            [(0uz7ktrk5jmlmzq, #tigrai), (2d9cx8mvd7, #kno...
# 4            [(2d9cx8mvd7, #ethiopia), (5sd2gygxnkfk7eb, #a...
# 5            [(0uz7ktrk5jmlmzq, #tigraygenocide), (abraham8...
# 6            [(2d9cx8mvd7, #tplfterroristgroup), (5sd2gygxn...
# 7            [(5sd2gygxnkfk7eb, #droneattacks), (abraham857...
# 8            [(akins_yusuf, #ethiopia), (amare_smere, #medi...
# 9            [(5sd2gygxnkfk7eb, #idps), (amare_smere, #ethi...
# 10           [(abraham85702013, #endtigraysiege), (akins_yu...

# %% [markdown]
# Create an undirected bipartite graph with hashtags and users as node types and frequencies as weights.

# %%
import networkx as nx
from networkx.algorithms import bipartite

B = nx.Graph()

# Add nodes with the node attribute "bipartite"
user_nodes = hashtags_vector.index.tolist()
hashtags_nodes = hashtags_vector.columns.tolist()
B.add_nodes_from(user_nodes, bipartite=0)
B.add_nodes_from(hashtags_nodes, bipartite=1)

# Add edges only between nodes of opposite node sets
for freq, row in freqs_pairs.iterrows():
    B.add_edges_from(row['edges'], weight=freq)

# %%
nx.write_gexf(B, path='output/ethiopia/bipartite.gexf')

# %%
nx.draw_networkx(B)
# Out:
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4808 (\N{ETHIOPIC SYLLABLE WA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4843 (\N{ETHIOPIC SYLLABLE YAA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4756 (\N{ETHIOPIC SYLLABLE NEE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4757 (\N{ETHIOPIC SYLLABLE NE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4611 (\N{ETHIOPIC SYLLABLE HAA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4872 (\N{ETHIOPIC SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4653 (\N{ETHIOPIC SYLLABLE RE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4612 (\N{ETHIOPIC SYLLABLE HEE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4634 (\N{ETHIOPIC SYLLABLE MI}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4613 (\N{ETHIOPIC SYLLABLE HE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4829 (\N{ETHIOPIC SYLLABLE ZE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4709 (\N{ETHIOPIC SYLLABLE BE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4619 (\N{ETHIOPIC SYLLABLE LAA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4618 (\N{ETHIOPIC SYLLABLE LI}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4704 (\N{ETHIOPIC SYLLABLE BA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4632 (\N{ETHIOPIC SYLLABLE MA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4621 (\N{ETHIOPIC SYLLABLE LE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4779 (\N{ETHIOPIC SYLLABLE KAA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4637 (\N{ETHIOPIC SYLLABLE ME}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4755 (\N{ETHIOPIC SYLLABLE NAA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4650 (\N{ETHIOPIC SYLLABLE RI}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4635 (\N{ETHIOPIC SYLLABLE MAA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4771 (\N{ETHIOPIC SYLLABLE GLOTTAL AA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4850 (\N{ETHIOPIC SYLLABLE DI}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4941 (\N{ETHIOPIC SYLLABLE FE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4677 (\N{ETHIOPIC SYLLABLE QE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4725 (\N{ETHIOPIC SYLLABLE TE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4877 (\N{ETHIOPIC SYLLABLE GE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4651 (\N{ETHIOPIC SYLLABLE RAA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4845 (\N{ETHIOPIC SYLLABLE YE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4675 (\N{ETHIOPIC SYLLABLE QAA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4658 (\N{ETHIOPIC SYLLABLE SI}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4661 (\N{ETHIOPIC SYLLABLE SE}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4768 (\N{ETHIOPIC SYLLABLE GLOTTAL A}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4707 (\N{ETHIOPIC SYLLABLE BAA}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 4726 (\N{ETHIOPIC SYLLABLE TO}) missing from current font.
#   func(*args, **kwargs)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 
E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4950 (\N{ETHIOPIC SYLLABLE PO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4722 (\N{ETHIOPIC SYLLABLE TI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Plot cumulated sum of how many known context hashtags are present wrt to number of frequencies cuts.

# %%
context_hashtag_list = ah.get_contexts()['hashtags'].str.split().sum()

hashtags_degree = pd.DataFrame(list(B.degree(hashtags_nodes)), columns=['hashtag', 'degree'])
hashtags_degree['in_topic'] = hashtags_degree['hashtag'].isin(context_hashtag_list).astype(int)
hashtags_degree = hashtags_degree.groupby('degree').sum().squeeze().cumsum()
hashtags_degree
# Out:
# degree
# 1     0
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 7     2
# 8     2
# 9     3
# 10    3
# 11    3
# 12    3
# 13    3
# 14    3
# 15    3
# 16    3
# 18    4
# 19    4
# 20    4
# 21    4
# 22    4
# 25    5
# 26    5
# 28    5
# 29    5
# 34    5
# 35    6
# 37    7
# 47    8
# Name: in_topic, dtype: int64

# %%
ax = hashtags_degree.plot(figsize=(20, 10))
ax.set(xlabel='degree',
       ylabel='# in-topic hashtags',
       title='Cumsum of in-topic hashtags wrt degree',
       xticks=np.arange(0, hashtags_degree.index.max(), step=10));

# %% [markdown]
# ## Users and hashtags network

# %%
def get_graph(network_df, network_name):
    graph = nx.Graph()

    # create nodes and edges
    nodes = pd.concat([network_df[network_df.columns[0]], network_df[network_df.columns[1]]], axis=0)\
    .drop_duplicates().tolist()
    edges = network_df.to_records(index=False).tolist()

    # add nodes and edges to graph
    graph.add_nodes_from(nodes)
    graph.add_weighted_edges_from(edges)

    # save graph
    nx.write_gexf(graph,
                  path='output/ethiopia/' +
                  network_name + '.gexf')
    
    return graph

# %% [markdown]
# ### Users network

# %%
users_network = ah.get_users_network()
users_graph = get_graph(users_network, 'users_network')
# Out:
# datasource.files.read: full file name =   user_network.csv

# %% [markdown]
# ### Hashtags network

# %%
hashtags_network = ah.get_hashtags_network()
hashtags_graph = get_graph(hashtags_network, 'hashtags_network')
# Out:
# datasource.files.read: full file name =   hashtag_network.csv

# %% [markdown]
# ## Add weights to bipartite graph

# %%
users = [node for node, node_type in B.nodes(data='bipartite') if node_type == 0]
filtered_users_network = users_network[users_network['from_username'].isin(users) &
                                       users_network['to_username'].isin(users)].reset_index(drop=True)

# %%
hashtags = [node for node, node_type in B.nodes(data='bipartite') if node_type == 1]
filtered_hashtags_network = hashtags_network[hashtags_network['from_hashtag'].isin(hashtags) &
                                             hashtags_network['to_hashtag'].isin(users)].reset_index(drop=True)

# %%
users_network_edges = filtered_users_network.to_records(index=False).tolist()
B.add_weighted_edges_from(users_network_edges)

hashtags_network_edges = filtered_hashtags_network.to_records(index=False).tolist()
B.add_weighted_edges_from(hashtags_network_edges)

# save graph
nx.write_gexf(B,
              path='output/ethiopia/bipartite_complete.gexf')

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 14, 10
pos = nx.spring_layout(B, scale=20, k=3/np.sqrt(B.order()))
colors = [['lightgrey', 'lightblue'][node.startswith('tig')] 
          for node in B.nodes()]
d = dict(B.degree)
nx.draw(B, pos, 
        with_labels=True, 
        #nodelist=d, 
        node_size=[d[k]*30 for k in d],
        node_color=colors)

#nx.draw_networkx(B)
# Out:
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 
YLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4853 (\N{ETHIOPIC SYLLABLE DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4614 (\N{ETHIOPIC SYLLABLE HO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4720 (\N{ETHIOPIC SYLLABLE TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4848 (\N{ETHIOPIC SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4874 (\N{ETHIOPIC SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4648 (\N{ETHIOPIC SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4875 (\N{ETHIOPIC SYLLABLE GAA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4649 (\N{ETHIOPIC SYLLABLE RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4811 (\N{ETHIOPIC SYLLABLE WAA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4752 (\N{ETHIOPIC SYLLABLE NA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4721 (\N{ETHIOPIC SYLLABLE TU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4896 (\N{ETHIOPIC SYLLABLE THA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4765 (\N{ETHIOPIC SYLLABLE NYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4678 (\N{ETHIOPIC SYLLABLE QO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4627 (\N{ETHIOPIC SYLLABLE HHAA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4706 (\N{ETHIOPIC SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4729 (\N{ETHIOPIC SYLLABLE CU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4770 (\N{ETHIOPIC SYLLABLE GLOTTAL I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4846 (\N{ETHIOPIC SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4917 (\N{ETHIOPIC SYLLABLE PHE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4664 (\N{ETHIOPIC SYLLABLE SHA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4939 (\N{ETHIOPIC SYLLABLE FAA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4616 (\N{ETHIOPIC SYLLABLE LA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4844 (\N{ETHIOPIC SYLLABLE YEE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4773 (\N{ETHIOPIC SYLLABLE GLOTTAL E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4873 (\N{ETHIOPIC SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4776 (\N{ETHIOPIC SYLLABLE KA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4826 (\N{ETHIOPIC SYLLABLE ZI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4827 (\N{ETHIOPIC SYLLABLE ZAA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4609 (\N{ETHIOPIC SYLLABLE HU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4819 (\N{ETHIOPIC SYLLABLE PHARYNGEAL AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4840 (\N{ETHIOPIC SYLLABLE YA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4824 (\N{ETHIOPIC SYLLABLE ZA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4835 (\N{ETHIOPIC SYLLABLE ZHAA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4724 (\N{ETHIOPIC SYLLABLE TEE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4930 (\N{ETHIOPIC SYLLABLE TZI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4864 (\N{ETHIOPIC SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4876 (\N{ETHIOPIC SYLLABLE GEE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4828 (\N{ETHIOPIC SYLLABLE ZEE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4705 (\N{ETHIOPIC SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4813 (\N{ETHIOPIC SYLLABLE WE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4901 (\N{ETHIOPIC SYLLABLE THE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4676 (\N{ETHIOPIC SYLLABLE QEE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4950 (\N{ETHIOPIC SYLLABLE PO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda/envs/twit/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 4722 (\N{ETHIOPIC SYLLABLE TI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
B['azeneelias']
# Out:
# AtlasView({'#abiy': {'weight': 1}, '#airstrikes': {'weight': 1}, '#ethiopian': {'weight': 1}, '#euactnow': {'weight': 1}, '#medicalsupplyfortigray': {'weight': 1}, '#newyear': {'weight': 1}, '#nobelpeaceprize': {'weight': 1}, '#noflyzoneintigray': {'weight': 1}, '#saudiarabia': {'weight': 1}, '#stoptigrayfamine': {'weight': 1}, '#stoptigraysiege': {'weight': 1}, '#tigrayans': {'weight': 1}, '#tigraygenocide': {'weight': 1}, '#tigraygenoicde': {'weight': 1}, '#unactnow': {'weight': 1}, '#endtigraysiege': {'weight': 2}, '#stoptigraygenocide': {'weight': 2}, '#tigrayissuffering': {'weight': 2}, '#uae': {'weight': 2}, '#ethiopia': {'weight': 3}, '#tigray': {'weight': 4}})

# %%
#https://ericmjl.github.io/nxviz/api/mid-level-api/

import nxviz as nv
ax = nv.arc(
    B,
    #group_by="group",
    #sort_by='weight',
    #node_color_by='name',
    edge_alpha_by="weight"
)

#nv.annotate.circos_group(B)

# %% [markdown]
# ## Correlations between users wrt hashtags

# %%
users_corr = ah.get_users_corr()
#sns.clustermap(users_corr);
# Out:
# datasource.files.read: full file name =   corr_users.csv

# %%
# from sklearn.cluster import AgglomerativeClustering
# import numpy as np
# X = users_corr.values
# clustering = AgglomerativeClustering().fit(X) 
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto', linkage='ward')
# list(zip(clustering.labels_, users_corr.index))

# %%
import numpy as np; import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
hashtags_vector = ah.get_bow()

M_u = hashtags_vector.mean(axis=1)
item_mean_subtracted = hashtags_vector - M_u[:, None]
csim = cosine_similarity(item_mean_subtracted)
csim = pd.DataFrame(data=csim,
                    index=hashtags_vector.index,
                    columns=hashtags_vector.index)
# Out:
# datasource.files.read: full file name =   user_hashtag_network.csv
# /tmp/ipykernel_8864/2174983068.py:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   item_mean_subtracted = hashtags_vector - M_u[:, None]

# %%
sns.clustermap(csim);

# %%
from scipy.cluster.hierarchy import dendrogram, linkage  
from matplotlib import pyplot as plt

linked = linkage(csim.values, 'ward')

plt.figure(figsize=(10, 50))  
dendrogram(linked,
           labels=csim.index,
           orientation='right',
           distance_sort='descending',
           leaf_font_size=12.,
           show_leaf_counts=True)
plt.show()

# %%
def fancy_dendrogram(*args, **kwargs):
    max_d = kwargs.pop('max_d', None)
    if max_d and 'color_threshold' not in kwargs:
        kwargs['color_threshold'] = max_d
    annotate_above = kwargs.pop('annotate_above', 0)

    ddata = dendrogram(*args, **kwargs)

    if not kwargs.get('no_plot', False):
        plt.title('Hierarchical Clustering Dendrogram (truncated)')
        plt.xlabel('sample index or (cluster size)')
        plt.ylabel('distance')
        for i, d, c in zip(ddata['icoord'], ddata['dcoord'], ddata['color_list']):
            x = 0.5 * sum(i[1:3])
            y = d[1]
            if y > annotate_above:
                plt.plot(x, y, 'o', c=c)
                plt.annotate("%.3g" % y, (x, y), xytext=(0, -5),
                             textcoords='offset points',
                             va='top', ha='center')
        if max_d:
            plt.axhline(y=max_d, c='k')
    return ddata

# %%
plt.figure(figsize=(10, 50))

# dendrogram(linked,
#            labels=csim.index,
#            orientation='right',
#            distance_sort='descending',
#            leaf_font_size=12.,
#            show_leaf_counts=True)

fancy_dendrogram(
    linked,
    labels=csim.index,
    orientation='right',
    distance_sort='descending',
    truncate_mode='lastp',
    show_leaf_counts=True,
    
    p=12,
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,
    annotate_above=10,  # useful in small plots so annotations don't overlap
)
plt.show()

# %% [markdown]
# # KMEANS

# %%
hashtags_vector = ah.get_bow()

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
from sklearn.pipeline import make_pipeline
import pandas as pd
from sklearn import metrics

# %%
svd = TruncatedSVD(n_components=150, n_iter=7, random_state=42)
svd.fit(hashtags_vector)
print(svd.explained_variance_ratio_)
print(svd.explained_variance_ratio_.sum())
print(svd.singular_values_)

explained_variance = svd.explained_variance_ratio_.sum()
print("Explained variance of the SVD step: {}%".format(int(explained_variance * 100)))

normalizer = Normalizer(copy=False)
lsa = make_pipeline(svd, normalizer)

X = lsa.fit_transform(hashtags_vector)
# Out:
# [0.17511945 0.03862288 0.03668477 0.03210138 0.02512089 0.02390875
#   109.93582687  109.44935026  108.28534694  108.04584961  107.91605291
#   107.42442307  106.53152225  105.94530707  105.24753808  104.94049527
#   102.72959636  100.7623952    99.87848255   99.66219391   98.3521457
#    97.65272835   97.19163161   97.056204     95.19920905   94.43163446
#    93.46278921   92.24328879   91.19550501   89.18039569   88.90711677
#    87.7080798    87.38277569   87.21017388   87.13451537   86.87752216
#    86.18160998   86.02416314   85.48654663   85.30917487   84.95508514
#    84.4249313    84.28239758   83.88020422   83.55677645   83.41825226
#    83.16583349   82.88894021   82.66019689   82.39629128   81.45370128
#    81.29464421   80.47077312   79.95664717   79.50791802   79.33889954
#    79.25849047   79.06594877   78.63929965   78.31037941   77.7634993
#    77.65382361   77.49787151   77.18538867   76.6706807    76.46789466]
# Explained variance of the SVD step: 88%

# %%
km = KMeans(n_clusters=len(o.datasources.contexts.get_context_names()))
km.fit(X)
# Get cluster assignment labels
labels = km.labels_
# Format results as a DataFrame
results = pd.DataFrame([hashtags_vector.index, labels]).T

# %%
print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels, km.labels_))
print("Completeness: %0.3f" % metrics.completeness_score(labels, km.labels_))
print("V-measure: %0.3f" % metrics.v_measure_score(labels, km.labels_))
print("Adjusted Rand-Index: %.3f"
      % metrics.adjusted_rand_score(labels, km.labels_))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X, km.labels_, sample_size=1000))
# Out:
# Homogeneity: 1.000
# Completeness: 1.000
# V-measure: 1.000
# Adjusted Rand-Index: 1.000
# Silhouette Coefficient: 0.200

# %%
results[1].describe()
# Out:
# count     941
# unique     25
# top        11
# freq      208
# Name: 1, dtype: int64

# %%
resultss = results.rename(columns={0: 'user_name', 1: 'cluster'}).sort_values(by='cluster').reset_index(drop=True)
resultss
# Out:
#            user_name cluster
# 0         castlemall       0
# 1        moralfibres       0
# 2      choctradingco       0
# 3          tnorwich1       0
# 4    norfolkwheadway       0
# ..               ...     ...
# 936   salfordcarers1      24
# 937       coppolaali      24
# 938   alysonthomas21      24
# 939   pearson17colin      24
# 940   triangleofcare      24
#
# [941 rows x 2 columns]

# %%
for c in o.datasources.contexts.get_context_names():
    context_users = o.datasources.files.read('network_creation', 'create_nodes', 'nodes', 'csv', c)['user_name']
    resultss[c] = resultss['user_name'].isin(context_users)
clusters = resultss.groupby('cluster').sum().idxmax(axis=1).to_frame().rename(columns={0: 'context'})
clusters['size'] = resultss.groupby('cluster').size()
clusters['value'] = resultss.groupby('cluster').sum().apply(max, axis=1).astype(int)
clusters['ratio'] = (clusters['value'] / clusters['size']).round(2)
print(f'unique contexts number: {clusters.context.nunique()}')
clusters
# Out:
# datasource.files.read: full file name =   ethiopia-national-dialogue__nodes.csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15331/3100312502.py in <module>
#       1 for c in o.datasources.contexts.get_context_names():
#       2     context_users = o.datasources.files.read('network_creation', 'create_nodes', 'nodes', 'csv', c)['user_name']
# ----> 3     resultss[c] = resultss['user_name'].isin(context_users)
#       4 clusters = resultss.groupby('cluster').sum().idxmax(axis=1).to_frame().rename(columns={0: 'context'})
#       5 clusters['size'] = resultss.groupby('cluster').size()
#
# NameError: name 'resultss' is not defined
